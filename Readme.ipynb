# %%
# To display a directory structure in a Jupyter notebook, you can:
# 1. Use a markdown cell instead of a code cell
# 2. Or print it as a multi-line string if you need to show it from Python

# Option 1: Create a markdown cell and paste the directory structure there
# (This is the recommended approach)

# Option 2: If you need to display it from Python code:
directory_structure = """
AI-Tools-Assignment/
├── README.md
├── requirements.txt
├── Part1_Theory_Answers.pdf
├── screenshots/
│   ├── iris_confusion_matrix.png
│   ├── mnist_accuracy_plot.png
│   └── spacy_ner_output.png
│
├── notebooks/
│   ├── iris_decision_tree.ipynb        # Scikit-learn task
│   ├── mnist_cnn.ipynb                 # TensorFlow task
│   └── amazon_spacy_nlp.ipynb          # spaCy NLP task
│
├── data/
│   └── sample_reviews.csv
│
└── deployment/
    └── streamlit_app.py                # Bonus deployment task
"""

print(directory_structure)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.12.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
